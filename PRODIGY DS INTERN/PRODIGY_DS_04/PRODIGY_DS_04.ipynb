# %% [markdown]
# > **Task 4**
# >
# **Analyze and visualize sentiment patterns in social media data to understand public opinion and attitudes towards specific topics or brands**

# %%
#Importing Necessary Libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('twitter_training.csv',names=['ID','Game','Sentiment','Text'])
df
# Out:
#          ID         Game Sentiment  \
# 0      2401  Borderlands  Positive
# 1      2401  Borderlands  Positive
# 2      2401  Borderlands  Positive
# 3      2401  Borderlands  Positive
# 4      2401  Borderlands  Positive
# ...     ...          ...       ...
# 74677  9200       Nvidia  Positive
# 74678  9200       Nvidia  Positive
# 74679  9200       Nvidia  Positive
# 74680  9200       Nvidia  Positive
# 74681  9200       Nvidia  Positive
#
#                                                     Text
# 0      im getting on borderlands and i will murder yo...
# 1      I am coming to the borders and I will kill you...
# 2      im getting on borderlands and i will kill you ...
# 3      im coming on borderlands and i will murder you...
# 4      im getting on borderlands 2 and i will murder ...
# ...                                                  ...
# 74677  Just realized that the Windows partition of my...
# 74678  Just realized that my Mac window partition is ...
# ...

# %%
df.head()
# Out:
#      ID         Game Sentiment  \
# 0  2401  Borderlands  Positive
# 1  2401  Borderlands  Positive
# 2  2401  Borderlands  Positive
# 3  2401  Borderlands  Positive
# 4  2401  Borderlands  Positive
#
#                                                 Text
# 0  im getting on borderlands and i will murder yo...
# 1  I am coming to the borders and I will kill you...
# 2  im getting on borderlands and i will kill you ...
# 3  im coming on borderlands and i will murder you...
# 4  im getting on borderlands 2 and i will murder ...

# %%
df.tail()
# Out:
#          ID    Game Sentiment  \
# 74677  9200  Nvidia  Positive
# 74678  9200  Nvidia  Positive
# 74679  9200  Nvidia  Positive
# 74680  9200  Nvidia  Positive
# 74681  9200  Nvidia  Positive
#
#                                                     Text
# 74677  Just realized that the Windows partition of my...
# 74678  Just realized that my Mac window partition is ...
# 74679  Just realized the windows partition of my Mac ...
# 74680  Just realized between the windows partition of...
# 74681  Just like the windows partition of my Mac is l...

# %%
df.columns
# Out:
# Index(['ID', 'Game', 'Sentiment', 'Text'], dtype='object')

# %%
df.shape
# Out:
# (74682, 4)

# %%
df.info
# Out:
# <bound method DataFrame.info of          ID         Game Sentiment  \
# 0      2401  Borderlands  Positive
# 1      2401  Borderlands  Positive
# 2      2401  Borderlands  Positive
# 3      2401  Borderlands  Positive
# 4      2401  Borderlands  Positive
# ...     ...          ...       ...
# 74677  9200       Nvidia  Positive
# 74678  9200       Nvidia  Positive
# 74679  9200       Nvidia  Positive
# 74680  9200       Nvidia  Positive
# 74681  9200       Nvidia  Positive
#
#                                                     Text
# 0      im getting on borderlands and i will murder yo...
# 1      I am coming to the borders and I will kill you...
# 2      im getting on borderlands and i will kill you ...
# 3      im coming on borderlands and i will murder you...
# 4      im getting on borderlands 2 and i will murder ...
# ...                                                  ...
# 74677  Just realized that the Windows partition of my...
# ...

# %%
df.describe()
# Out:
#                  ID
# count  74682.000000
# mean    6432.586165
# std     3740.427870
# min        1.000000
# 25%     3195.000000
# 50%     6422.000000
# 75%     9601.000000
# max    13200.000000

# %% [markdown]
# **Data Preprocessing**

# %%
df.isnull().sum()
# Out:
# ID             0
# Game           0
# Sentiment      0
# Text         686
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 2700

# %% [markdown]
# **dropping missing and duplicated rows**

# %%
# df.dropna(inplace=True)
# df.drop_duplicates(inplace=True)

df.replace('unknown', pd.NA)
# Out:
#          ID         Game Sentiment  \
# 0      2401  Borderlands  Positive
# 1      2401  Borderlands  Positive
# 2      2401  Borderlands  Positive
# 3      2401  Borderlands  Positive
# 4      2401  Borderlands  Positive
# ...     ...          ...       ...
# 74677  9200       Nvidia  Positive
# 74678  9200       Nvidia  Positive
# 74679  9200       Nvidia  Positive
# 74680  9200       Nvidia  Positive
# 74681  9200       Nvidia  Positive
#
#                                                     Text
# 0      im getting on borderlands and i will murder yo...
# 1      I am coming to the borders and I will kill you...
# 2      im getting on borderlands and i will kill you ...
# 3      im coming on borderlands and i will murder you...
# 4      im getting on borderlands 2 and i will murder ...
# ...                                                  ...
# 74677  Just realized that the Windows partition of my...
# 74678  Just realized that my Mac window partition is ...
# ...

# %%
df.isnull().sum()
# Out:
# ID             0
# Game           0
# Sentiment      0
# Text         686
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 2700

# %% [markdown]
# **Data Visualization**

# %%
gameCounts = df['Game'].value_counts() #game count of gamewise
gameCounts
# Out:
# TomClancysRainbowSix                 2400
# MaddenNFL                            2400
# Microsoft                            2400
# LeagueOfLegends                      2394
# CallOfDuty                           2394
# Verizon                              2382
# CallOfDutyBlackopsColdWar            2376
# ApexLegends                          2376
# Facebook                             2370
# WorldOfCraft                         2364
# Dota2                                2364
# NBA2K                                2352
# TomClancysGhostRecon                 2346
# Battlefield                          2346
# FIFA                                 2340
# Xbox(Xseries)                        2334
# Overwatch                            2334
# johnson&johnson                      2328
# Amazon                               2316
# PlayStation5(PS5)                    2310
# HomeDepot                            2310
# Cyberpunk2077                        2304
# ...

# %%
gameCountPercent = round((gameCounts/len(df)) * 100,2)
gameCountPercent
# Out:
# TomClancysRainbowSix                 3.21
# MaddenNFL                            3.21
# Microsoft                            3.21
# LeagueOfLegends                      3.21
# CallOfDuty                           3.21
# Verizon                              3.19
# CallOfDutyBlackopsColdWar            3.18
# ApexLegends                          3.18
# Facebook                             3.17
# WorldOfCraft                         3.17
# Dota2                                3.17
# NBA2K                                3.15
# TomClancysGhostRecon                 3.14
# Battlefield                          3.14
# FIFA                                 3.13
# Xbox(Xseries)                        3.13
# Overwatch                            3.13
# johnson&johnson                      3.12
# Amazon                               3.10
# PlayStation5(PS5)                    3.09
# HomeDepot                            3.09
# Cyberpunk2077                        3.09
# ...

# %%
#plotting horizontal Bar graph
plt.figure(figsize=(8,10))
gameCountPercent.plot(kind="barh",color="lightgreen")

plt.title("Game Distribution (Percent)")
plt.xlabel("Percentage")
plt.ylabel("Game")
plt.show()

# %% [markdown]
# **Sentiment Analysis**

# %%
df['Sentiment'].count()
# Out:
# 74682

# %%
sns.countplot(x="Sentiment",data=df,palette='viridis')
plt.show()

# %%
sentiment_counts = df['Sentiment'].value_counts()
print("::: Sentiment Counts ::: ")
sentiment_counts
# Out:
# ::: Sentiment Counts :::
# Negative      22542
# Positive      20832
# Neutral       18318
# Irrelevant    12990
# Name: Sentiment, dtype: int64

# %%
#create a pie chart

plt.figure(figsize=(8,8))
plt.pie(
    sentiment_counts,
    labels=sentiment_counts.index,
    autopct="%1.1f%%",
    startangle=140,
    colors=['purple','orange','yellow','red']
)
plt.title("Sentiment Distribution")
plt.show()

# %%
sns.catplot(x="Game",hue="Sentiment", kind="count",height=10,aspect=3, data=df)

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >
